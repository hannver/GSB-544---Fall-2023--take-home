# %% [markdown]
# # Hanna Wierszok

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
train_data = pd.read_csv('/content/sample_data/CAH-201803-train.csv')
train_data
# Out:
#      id_num      Q1  Q2 political_affiliation            Q4  \
# 0         1    Male  53           Independent       Liberal
# 1         5  Female  66           Independent  Conservative
# 2         7  Female  58              Democrat       Liberal
# 3         8    Male  55           Independent      Moderate
# 4         9    Male  64            Republican  Conservative
# ..      ...     ...  ..                   ...           ...
# 164     325    Male  21            Republican  Conservative
# 165     328  Female  41            Republican       Liberal
# 166     329    Male  60            Republican  Conservative
# 167     332  Female  51            Republican  Conservative
# 168     335    Male  67            Republican      Moderate
#
#                       Q5     Q6   Q7   Q8   Q9                      Q10  \
# 0         College degree  Black   No   No   No  Yes, somewhat religious
# 1           Some college  White  Yes   No  Yes      Yes, very religious
# 2         College degree  White   No   No   No      Yes, very religious
# 3    High school or less  White  Yes  Yes  Yes  Yes, somewhat religious
# 4    High school or less  White  Yes  Yes  Yes                       No
# ..                   ...    ...  ...  ...  ...                      ...
# 164         Some college  White  Yes   No  Yes                       No
# 165      Graduate degree  White  Yes  Yes  Yes  Yes, somewhat religious
# 166         Some college  White  Yes  Yes  Yes  Yes, somewhat religious
# 167      Graduate degree  White  Yes  Yes  Yes      Yes, very religious
# 168  High school or less  White  Yes  Yes  Yes  Yes, somewhat religious
#
#             Q11  Q12  Q13                    Q14  Q15  Q16  Q17  Q18
# 0    Pro-Choice   No   No  Behave no differently    5    2    5   No
# 1      Pro-life  Yes  Yes           Less Willing    4    5    4   No
# 2    Pro-Choice   No   No  Behave no differently    5    1    4  Yes
# 3      Pro-life  Yes  Yes           Less Willing    4    5    4  Yes
# 4      Pro-life   No   No  Behave no differently    5    1    1  Yes
# ..          ...  ...  ...                    ...  ...  ...  ...  ...
# 164  Pro-Choice  Yes   No           Less Willing    5    2    5   No
# 165  Pro-Choice  Yes   No           Less Willing    5    2    2   No
# 166    Pro-life   No  Yes  Behave no differently    5    5    4  Yes
# 167    Pro-life  Yes   No           Less Willing    2    5    1   No
# 168    Pro-life  Yes   No  Behave no differently    5    5    4  Yes
#
# [169 rows x 19 columns]

# %%
train_data_cleaned = train_data.drop('id_num', axis=1).dropna()
train_data_cleaned
# Out:
#          Q1  Q2 political_affiliation            Q4                   Q5  \
# 0      Male  53           Independent       Liberal       College degree
# 1    Female  66           Independent  Conservative         Some college
# 2    Female  58              Democrat       Liberal       College degree
# 3      Male  55           Independent      Moderate  High school or less
# 4      Male  64            Republican  Conservative  High school or less
# ..      ...  ..                   ...           ...                  ...
# 164    Male  21            Republican  Conservative         Some college
# 165  Female  41            Republican       Liberal      Graduate degree
# 166    Male  60            Republican  Conservative         Some college
# 167  Female  51            Republican  Conservative      Graduate degree
# 168    Male  67            Republican      Moderate  High school or less
#
#         Q6   Q7   Q8   Q9                      Q10         Q11  Q12  Q13  \
# 0    Black   No   No   No  Yes, somewhat religious  Pro-Choice   No   No
# 1    White  Yes   No  Yes      Yes, very religious    Pro-life  Yes  Yes
# 2    White   No   No   No      Yes, very religious  Pro-Choice   No   No
# 3    White  Yes  Yes  Yes  Yes, somewhat religious    Pro-life  Yes  Yes
# 4    White  Yes  Yes  Yes                       No    Pro-life   No   No
# ..     ...  ...  ...  ...                      ...         ...  ...  ...
# 164  White  Yes   No  Yes                       No  Pro-Choice  Yes   No
# 165  White  Yes  Yes  Yes  Yes, somewhat religious  Pro-Choice  Yes   No
# 166  White  Yes  Yes  Yes  Yes, somewhat religious    Pro-life   No  Yes
# 167  White  Yes  Yes  Yes      Yes, very religious    Pro-life  Yes   No
# 168  White  Yes  Yes  Yes  Yes, somewhat religious    Pro-life  Yes   No
#
#                        Q14  Q15  Q16  Q17  Q18
# 0    Behave no differently    5    2    5   No
# 1             Less Willing    4    5    4   No
# 2    Behave no differently    5    1    4  Yes
# 3             Less Willing    4    5    4  Yes
# 4    Behave no differently    5    1    1  Yes
# ..                     ...  ...  ...  ...  ...
# 164           Less Willing    5    2    5   No
# 165           Less Willing    5    2    2   No
# 166  Behave no differently    5    5    4  Yes
# 167           Less Willing    2    5    1   No
# 168  Behave no differently    5    5    4  Yes
#
# [169 rows x 18 columns]

# %%
# Splitting the dataset into features (X) and target (y)
X = train_data_cleaned.drop('political_affiliation', axis=1)
y = train_data_cleaned['political_affiliation']

# Identifying categorical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# %% [markdown]
# Logistic regression

# %%
# Creating a Logistic Regression model
logreg_model = LogisticRegression(random_state=0, max_iter=1000)
logreg_pipeline = Pipeline(steps=[('preprocessor', preprocessor),
                                   ('classifier', logreg_model)])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
param_grid = {'classifier__C': [0.001, 0.01, 0.1, 1, 10, 100]}
grid_search = GridSearchCV(logreg_pipeline, param_grid=param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)
best_logreg_model = grid_search.best_estimator_
y_pred_logreg = best_logreg_model.predict(X_test)
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
print(f"Accuracy with Logistic Regression: {accuracy_logreg}")
test_data = pd.read_csv("/content/sample_data/CAH-201803-test.csv")
test_data_cleaned = test_data.drop(columns=['id_num']).dropna()
y_pred_logreg_test = best_logreg_model.predict(test_data_cleaned)
submission_logreg = pd.DataFrame()
submission_logreg['id_num'] = test_data['id_num']
submission_logreg['political_affiliation_predicted'] = y_pred_logreg_test
submission_logreg.head()
# Out:
# Accuracy with Logistic Regression: 0.6470588235294118
#    id_num political_affiliation_predicted
# 0       2                      Republican
# 1       3                     Independent
# 2       4                     Independent
# 3       6                      Republican
# 4      11                     Independent
